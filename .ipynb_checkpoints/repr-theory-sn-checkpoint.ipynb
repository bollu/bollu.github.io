# %% [markdown]
# # Dominance ordering of partitions
# For two partitions $\lambda, \mu \in Par(N)$, $\lambda$ dominates $\mu$ iff:
#
# $$
# \forall i, \sum_i \lambda_i < \sum_i \mu_i
# $$

# %%
l = Partition([3, 2, 1]); m = Partition([4, 1, 1])

# %%
print("m |> l ?= %s" % (m.dominates(l), ))
print("l <| m ?= %s" % (l.dominates(m), ))
l.pp(); m.pp()
# Out:
# m |> l ?= True
# l <| m ?= False
# ***
# **
# *
# ****
# *
# *

# %%
L = posets.IntegerPartitionsDominanceOrder(6)
print("%s" % L)
# Out:
# Finite lattice containing 11 elements
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-536616a5cafa> in <module>
#       1 L = posets.IntegerPartitionsDominanceOrder(Integer(6))
#       2 print("%s" % L)
# ----> 3 L.plot().latex()
#
# AttributeError: 'Graphics' object has no attribute 'latex'

# %%
# Out:
# Graphics object consisting of 24 graphics primitives
